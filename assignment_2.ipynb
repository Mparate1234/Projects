# %% [markdown]
# # Problem Statement 1:

# %%
import pandas as pd

# %%
top50=pd.read_csv("C:/Users/MANISH/python/top50spotify.csv")
top_song=pd.DataFrame(top50)
top_song
# Out:
#     SerialNo.                                         Track.Name  \
# 0           1                                           Señorita
# 1           2                                              China
# 2           3                      boyfriend (with Social House)
# 3           4                    Beautiful People (feat. Khalid)
# 4           5                        Goodbyes (Feat. Young Thug)
# 5           6                  I Don't Care (with Justin Bieber)
# 6           7                                             Ransom
# 7           8                                  How Do You Sleep?
# 8           9                              Old Town Road - Remix
# 9          10                                            bad guy
# 10         11                                           Callaita
# 11         12              Loco Contigo (feat. J. Balvin & Tyga)
# 12         13                                  Someone You Loved
# ...

# %%
top_song["Track.Name"]
# Out:
# 0                                              Señorita
# 1                                                 China
# 2                         boyfriend (with Social House)
# 3                       Beautiful People (feat. Khalid)
# 4                           Goodbyes (Feat. Young Thug)
# 5                     I Don't Care (with Justin Bieber)
# 6                                                Ransom
# 7                                     How Do You Sleep?
# 8                                 Old Town Road - Remix
# 9                                               bad guy
# 10                                             Callaita
# 11                Loco Contigo (feat. J. Balvin & Tyga)
# 12                                    Someone You Loved
# 13                                   Otro Trago - Remix
# 14             Money In The Grave (Drake ft. Rick Ross)
# 15                            No Guidance (feat. Drake)
# 16                                           LA CANCIÓN
# ...

# %%
top_song.iloc[0:10,5].mean()
# Out:
# 65.1

# %%
top_song.iloc[0:10,10].mean()
# Out:
# 195.6

# %%
len_of_song=top_song.groupby("Genre")
len_of_song.size()
# Out:
# Genre
# atl hip hop         1
# australian pop      1
# big room            1
# boy band            1
# brostep             2
# canadian hip hop    3
# canadian pop        2
# country rap         2
# dance pop           8
# dfw rap             2
# edm                 3
# electropop          2
# escape room         1
# latin               5
# panamanian pop      2
# pop                 7
# pop house           1
# r&b en espanol      1
# reggaeton           2
# reggaeton flow      2
# trap music          1
# dtype: int64

# %%
a=top_song.groupby("Genre").get_group("dance pop")
a
# Out:
#     SerialNo.                                         Track.Name  \
# 2           3                      boyfriend (with Social House)
# 11         12              Loco Contigo (feat. J. Balvin & Tyga)
# 15         16                          No Guidance (feat. Drake)
# 31         32                                            7 rings
# 34         35                                  Never Really Over
# 39         40  fuck, i'm lonely (with Anne-Marie) - from “13 ...
# 41         42                              You Need To Calm Down
# 42         43                                            Shallow
#
#       Artist.Name      Genre  Beats.Per.Minute  Energy  Danceability  \
# 2   Ariana Grande  dance pop               190      80            40
# 11       DJ Snake  dance pop                96      71            82
# 15    Chris Brown  dance pop                93      45            70
# 31  Ariana Grande  dance pop               140      32            78
# ...

# %%
a.groupby("Artist.Name")["Genre"].count().head(1)
# Out:
# Artist.Name
# Ariana Grande    2
# Name: Genre, dtype: int64

# %% [markdown]
# # Problem Statement 2:

# %%
import pandas as pd

data={'English':{'Sam':60,'Jackson':74,'Ahree':85},'History':{'Gloria':83,'Sam':65,'Isla':78,'Aron':72,'Gray':61},'Geography':{'Jackson':92,'Gloria':95,'Isla':82,'Aron':75,'Ahree':76},'Mathematics':{'Sam':99,'Gloria':74,'Jackson':89,'Ahree':85,'Gray':95},'Science':{'Sam':89,'Aron':82,'Gray':78,'Isla':93,'Ahree':87}}
df=pd.DataFrame(data)
df
# Out:
#          English  History  Geography  Mathematics  Science
# Sam         60.0     65.0        NaN         99.0     89.0
# Jackson     74.0      NaN       92.0         89.0      NaN
# Ahree       85.0      NaN       76.0         85.0     87.0
# Gloria       NaN     83.0       95.0         74.0      NaN
# Isla         NaN     78.0       82.0          NaN     93.0
# Aron         NaN     72.0       75.0          NaN     82.0
# Gray         NaN     61.0        NaN         95.0     78.0

# %%
df1=df.fillna("0")
df1
# Out:
#         English History Geography Mathematics Science
# Sam        60.0    65.0         0        99.0    89.0
# Jackson    74.0       0      92.0        89.0       0
# Ahree      85.0       0      76.0        85.0    87.0
# Gloria        0    83.0      95.0        74.0       0
# Isla          0    78.0      82.0           0    93.0
# Aron          0    72.0      75.0           0    82.0
# Gray          0    61.0         0        95.0    78.0

# %%
row_mean = df.mean(axis=1)
print(row_mean)
# Out:
# Sam        78.250000
# Jackson    85.000000
# Ahree      83.250000
# Gloria     84.000000
# Isla       84.333333
# Aron       76.333333
# Gray       78.000000
# dtype: float64

# %%
df['row_mean'] = row_mean
df
# Out:
#          English  History  Geography  Mathematics  Science   row_mean
# Sam         60.0     65.0        NaN         99.0     89.0  78.250000
# Jackson     74.0      NaN       92.0         89.0      NaN  85.000000
# Ahree       85.0      NaN       76.0         85.0     87.0  83.250000
# Gloria       NaN     83.0       95.0         74.0      NaN  84.000000
# Isla         NaN     78.0       82.0          NaN     93.0  84.333333
# Aron         NaN     72.0       75.0          NaN     82.0  76.333333
# Gray         NaN     61.0        NaN         95.0     78.0  78.000000

# %% [markdown]
# # Problem Statement 3:

# %%
import numpy as np 
sr=np.arange(1,1001)
sr
div_7_and_17=[]
for i in sr:
    if i%7==0 and i%17==0:
        div_7_and_17.append(i)
print("numbers divisible by 7 and 17",div_7_and_17)
# Out:
# numbers divisible by 7 and 17 [119, 238, 357, 476, 595, 714, 833, 952]

# %% [markdown]
# # Problem Statement 4:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv("C:/Users/MANISH/python/cereal_csv.csv")
data#.head()
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
x=data["mfr"].values.reshape(-1,1)
y=data["rating"].values.reshape(-1,1)
plt.figure()
plt.scatter(data["mfr"],data["rating"],c="r",marker="+")
plt.xlabel("mfr")
plt.ylabel("rating")
plt.show()
